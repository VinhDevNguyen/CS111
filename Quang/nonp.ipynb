# %%
import hashlib
file = open('syllables.txt', mode = 'r', encoding= 'utf-8')
hashMD5File = open('md5hash.txt', mode = 'w+')

#Create hash key
for line in file:
    line = file.readline() 
    line = hashlib.md5(line.encode()).hexdigest()[:3:]
    hashMD5File.write(line)

# %%
# Pre-processing 
# Create dictionary <key,value> 
import hashlib
from collections import OrderedDict
import pandas as pd 
import numpy as np 
fileName = 'syllables.txt' 
# Create hash key
    # TODO: Remember to change mode to 'a' 
    # So that next time function won't rewrite 
hashList = []
with open(fileName,mode = 'r',encoding= 'utf-8') as file: 
    rawFileInput = file.readlines() 
    for line in rawFileInput: 
        line = hashlib.md5(line.encode()).hexdigest()[:3:]
        hashList.append(line)

def removeDuplicate(inputList): 
    return list(OrderedDict.fromkeys(inputList))

removeDuplicate(hashList)

def fillKeyOnly(listOfKey,myDict):
    myDict = {key: None for key in listOfKey} 
    return myDict

# %%
fillKeyOnly(hashList, 'None')
# Out:
# {'bf0': None,
#  '219': None,
#  '024': None,
#  '9d8': None,
#  'db3': None,
#  '68f': None,
#  '04e': None,
#  'dc6': None,
#  'a23': None,
#  '309': None,
#  '00a': None,
#  '813': None,
#  '899': None,
#  '0c9': None,
#  '22b': None,
#  '87b': None,
#  'bd3': None,
#  '7f4': None,
#  '368': None,
#  '19e': None,
#  'fe8': None,
#  '00c': None,
#  '4f9': None,
#  'a99': None,
#  '667': None,
#  '5b1': None,
#  '53f': None,
#  '16e': None,
#  '9fb': None,
#  '3a3': None,
#  'e2e': None,
#  '70b': None,
#  '462': None,
#  '0b8': None,
#  '60e': None,
#  '06f': None,
#  '015': None,
#  '172': None,
#  'e7c': None,
#  '3f3': None,
#  '8a4': None,
#  '3f2': None,
#  '37d': None,
#  '426': None,
#  '29f': None,
#  '782': None,
#  '966': None,
#  '3a9': None,
#  '0a2': None,
#  '01b': None,
#  'e29': None,
#  '434': None,
#  '6ac': None,
#  '527': None,
#  'ee6': None,
#  'e14': None,
#  '50b': None,
#  'd28': None,
#  'c4e': None,
#  '872': None,
#  'f55': None,
#  '9cb': None,
#  'c6c': None,
#  '73f': None,
#  '5a5': None,
#  '0cc': None,
#  '99b': None,
#  'efb': None,
#  'c36': None,
#  '2cd': None,
#  '276': None,
#  'be5': None,
#  '8cf': None,
#  '264': None,
#  '666': None,
#  '67e': None,
#  '57e': None,
#  '74a': None,
#  '7c5': None,
#  '9a2': None,
#  '766': None,
#  'ffa': None,
#  'b60': None,
#  '400': None,
#  '3a8': None,
#  'eca': None,
#  'a2c': None,
#  'e40': None,
#  '8f4': None,
#  'd6f': None,
#  '59e': None,
#  'e0d': None,
#  'fcd': None,
#  'cc4': None,
#  'ad1': None,
#  '4b7': None,
#  'b28': None,
#  '3b2': None,
#  'e2a': None,
#  'ebe': None,
#  'b0b': None,
#  '051': None,
#  'b32': None,
#  '48a': None,
#  '478': None,
#  'e71': None,
#  '198': None,
#  '3fc': None,
#  '120': None,
#  '029': None,
#  '1bf': None,
#  'b57': None,
#  'cbb': None,
#  '49b': None,
#  'a6e': None,
#  'f46': None,
#  '712': None,
#  '181': None,
#  '286': None,
#  'a8b': None,
#  '563': None,
#  '905': None,
#  'abb': None,
#  '4a5': None,
#  '2b5': None,
#  '850': None,
#  '99c': None,
#  '1e5': None,
#  '0fb': None,
#  'b88': None,
#  'a89': None,
#  '273': None,
#  '579': None,
#  '1e0': None,
#  '981': None,
#  '351': None,
#  '427': None,
#  '65c': None,
#  'd7b': None,
#  'd42': None,
#  '31f': None,
#  '941': None,
#  '318': None,
#  'e51': None,
#  'b63': None,
#  '8b9': None,
#  '05a': None,
#  '376': None,
#  '70f': None,
#  '30f': None,
#  '86a': None,
#  '4d3': None,
#  '38a': None,
#  '75f': None,
#  'f14': None,
#  '4ee': None,
#  'c19': None,
#  'ccb': None,
#  'df0': None,
#  'c18': None,
#  '854': None,
#  '7fb': None,
#  'cac': None,
#  'ae2': None,
#  '8ce': None,
#  '11f': None,
#  'a9b': None,
#  'a2e': None,
#  '521': None,
#  'fdb': None,
#  'd72': None,
#  'dc1': None,
#  '84c': None,
#  '403': None,
#  '3c2': None,
#  '965': None,
#  '050': None,
#  'aa1': None,
#  '352': None,
#  '809': None,
#  '097': None,
#  '9d5': None,
#  'f89': None,
#  '130': None,
#  '114': None,
#  '581': None,
#  'b9c': None,
#  '775': None,
#  '790': None,
#  'f5d': None,
#  'e0a': None,
#  '1dc': None,
#  '39b': None,
#  '8b4': None,
#  '013': None,
#  '557': None,
#  'f57': None,
#  'bca': None,
#  '83d': None,
#  'fda': None,
#  'd67': None,
#  '9fd': None,
#  '44f': None,
#  '432': None,
#  '5aa': None,
#  '9fc': None,
#  '8b2': None,
#  '060': None,
#  'b0f': None,
#  '2f8': None,
#  'e26': None,
#  '0ee': None,
#  '9c4': None,
#  '695': None,
#  '731': None,
#  'bd4': None,
#  '494': None,
#  '9ad': None,
#  '88b': None,
#  '9dc': None,
#  '719': None,
#  '780': None,
#  'de6': None,
#  'd01': None,
#  '9a4': None,
#  '2ff': None,
#  '6ee': None,
#  '33a': None,
#  'df8': None,
#  'b90': None,
#  '919': None,
#  'a86': None,
#  '402': None,
#  'e5b': None,
#  '30c': None,
#  '8f2': None,
#  '7d0': None,
#  'd1a': None,
#  '393': None,
#  'df7': None,
#  '42e': None,
#  'fd0': None,
#  '035': None,
#  '2d3': None,
#  '065': None,
#  '698': None,
#  'e6a': None,
#  '3c3': None,
#  'a0a': None,
#  '7ce': None,
#  'f4a': None,
#  '61e': None,
#  '805': None,
#  'aec': None,
#  '1fc': None,
#  '7f3': None,
#  '381': None,
#  'f70': None,
#  '3bd': None,
#  '702': None,
#  '29c': None,
#  '146': None,
#  '288': None,
#  '622': None,
#  '586': None,
#  '0c4': None,
#  '8e9': None,
#  '54a': None,
#  'c67': None,
#  'c17': None,
#  '398': None,
#  '4e4': None,
#  '76a': None,
#  'c12': None,
#  'f8c': None,
#  '86c': None,
#  'f59': None,
#  '59d': None,
#  '0b5': None,
#  '83f': None,
#  '6c9': None,
#  '409': None,
#  '844': None,
#  '7cb': None,
#  '6d6': None,
#  'f32': None,
#  'b22': None,
#  'c01': None,
#  'c87': None,
#  '216': None,
#  'f9e': None,
#  'db5': None,
#  '479': None,
#  '716': None,
#  '41b': None,
#  'b06': None,
#  '4f0': None,
#  'e39': None,
#  '8e5': None,
#  '996': None,
#  '595': None,
#  '284': None,
#  '4ff': None,
#  '807': None,
#  '781': None,
#  '372': None,
#  '3e3': None,
#  'fb5': None,
#  'eb2': None,
#  '75e': None,
#  '420': None,
#  'c80': None,
#  'ccc': None,
#  '725': None,
#  '138': None,
#  '230': None,
#  '44b': None,
#  'c4f': None,
#  'a1b': None,
#  '927': None,
#  '9e9': None,
#  'd8a': None,
#  '445': None,
#  '2bf': None,
#  '39f': None,
#  '387': None,
#  'cc7': None,
#  '852': None,
#  '0a9': None,
#  '06e': None,
#  '9e3': None,
#  'd44': None,
#  '068': None,
#  '19d': None,
#  '3b1': None,
#  '76b': None,
#  'f3e': None,
#  '7d4': None,
#  '9b0': None,
#  '19a': None,
#  'b68': None,
#  'a3c': None,
#  'e10': None,
#  'd45': None,
#  '7f8': None,
#  'ff2': None,
#  'c94': None,
#  '686': None,
#  '6a4': None,
#  '24f': None,
#  'f13': None,
#  '222': None,
#  '871': None,
#  'bcd': None,
#  'acd': None,
#  'a14': None,
#  '739': None,
#  '01d': None,
#  '1b9': None,
#  '0b1': None,
#  '1e1': None,
#  '226': None,
#  'fa6': None,
#  '34b': None,
#  '583': None,
#  '430': None,
#  '0f4': None,
#  'aa9': None,
#  '8c6': None,
#  '726': None,
#  '0f6': None,
#  'ab3': None,
#  '699': None,
#  'a87': None,
#  'c0e': None,
#  '16f': None,
#  '391': None,
#  '7fa': None,
#  'd3a': None,
#  'd4e': None,
#  'c2f': None,
#  '678': None,
#  '32f': None,
#  '4d6': None,
#  '874': None,
#  '157': None,
#  'a26': None,
#  '7bb': None,
#  '367': None,
#  '5dc': None,
#  'd11': None,
#  'acb': None,
#  'c5b': None,
#  'a58': None,
#  '340': None,
#  '789': None,
#  'd1b': None,
#  '7c9': None,
#  '2e8': None,
#  'f9b': None,
#  '3da': None,
#  'ca0': None,
#  '467': None,
#  '9b1': None,
#  '474': None,
#  'c6d': None,
#  'b40': None,
#  'c2d': None,
#  'fdc': None,
#  'b11': None,
#  'f8e': None,
#  '5a9': None,
#  '29e': None,
#  '460': None,
#  '147': None,
#  'cb1': None,
#  '4aa': None,
#  '96f': None,
#  'ee7': None,
#  'cc9': None,
#  'f63': None,
#  'bc3': None,
#  'b53': None,
#  '701': None,
#  '342': None,
#  '939': None,
#  '21f': None,
#  'ab0': None,
#  'e58': None,
#  'd38': None,
#  '23d': None,
#  'ec8': None,
#  'cf2': None,
#  'af4': None,
#  'd20': None,
#  '197': None,
#  '192': None,
#  '209': None,
#  '572': None,
#  'e7d': None,
#  '5d7': None,
#  'ac1': None,
#  '9a5': None,
#  'ad5': None,
#  '5eb': None,
#  'ae5': None,
#  '644': None,
#  '751': None,
#  '1a8': None,
#  '2ad': None,
#  '165': None,
#  '632': None,
#  '816': None,
#  'c6f': None,
#  'e7a': None,
#  'ac7': None,
#  '293': None,
#  'a96': None,
#  '3d7': None,
#  '72c': None,
#  '3ce': None,
#  '14e': None,
#  'c85': None,
#  '8c7': None,
#  '8bc': None,
#  'f72': None,
#  '480': None,
#  'b8b': None,
#  'a9f': None,
#  '6e1': None,
#  'c00': None,
#  '6d2': None,
#  '2e9': None,
#  '808': None,
#  '203': None,
#  'b5b': None,
#  '05b': None,
#  '485': None,
#  '64b': None,
#  'a7a': None,
#  '204': None,
#  '91b': None,
#  '817': None,
#  '25b': None,
#  '5a3': None,
#  '3c4': None,
#  '8ff': None,
#  'bce': None,
#  'b5a': None,
#  '075': None,
#  'e17': None,
#  '2b1': None,
#  'b1b': None,
#  '58a': None,
#  'a61': None,
#  '815': None,
#  'afe': None,
#  'd5e': None,
#  'b86': None,
#  'c8f': None,
#  '778': None,
#  'a08': None,
#  'c71': None,
#  '487': None,
#  'b2d': None,
#  '82b': None,
#  '0d7': None,
#  '3c5': None,
#  '27c': None,
#  '6e8': None,
#  'da1': None,
#  'f73': None,
#  'de1': None,
#  '11d': None,
#  'cef': None,
#  '892': None,
#  '824': None,
#  '2be': None,
#  '6c4': None,
#  '4c5': None,
#  '334': None,
#  '331': None,
#  '660': None,
#  'd78': None,
#  '186': None,
#  'c35': None,
#  '60f': None,
#  'b9a': None,
#  'c13': None,
#  '9e1': None,
#  '914': None,
#  '48e': None,
#  'b92': None,
#  '057': None,
#  '1d1': None,
#  'e85': None,
#  'c70': None,
#  '11b': None,
#  '50c': None,
#  'e1a': None,
#  'cd4': None,
#  '303': None,
#  '1c3': None,
#  '977': None,
#  '7dd': None,
#  '0bc': None,
#  'f1d': None,
#  '1f0': None,
#  '248': None,
#  'b37': None,
#  '6b4': None,
#  '683': None,
#  '0d9': None,
#  'bb3': None,
#  'f68': None,
#  'de5': None,
#  'da5': None,
#  'eec': None,
#  '85e': None,
#  '792': None,
#  '62b': None,
#  'a35': None,
#  '13e': None,
#  '638': None,
#  '5b8': None,
#  '66d': None,
#  '8e1': None,
#  '2d8': None,
#  'a9a': None,
#  '33f': None,
#  '1f7': None,
#  'a15': None,
#  'de9': None,
#  '1b7': None,
#  '149': None,
#  '693': None,
#  '568': None,
#  'f4e': None,
#  'dc0': None,
#  '964': None,
#  'ac0': None,
#  'c16': None,
#  'a98': None,
#  'fb9': None,
#  '764': None,
#  '1c1': None,
#  'f20': None,
#  '1e4': None,
#  'ef3': None,
#  '78b': None,
#  'b87': None,
#  'a4e': None,
#  'e61': None,
#  '03b': None,
#  'bfa': None,
#  'e67': None,
#  'ee0': None,
#  'e5e': None,
#  'd8c': None,
#  'ab4': None,
#  '861': None,
#  '77a': None,
#  '904': None,
#  '55c': None,
#  '41f': None,
#  '795': None,
#  'ad8': None,
#  '074': None,
#  '455': None,
#  '6f2': None,
#  'f7e': None,
#  'f39': None,
#  '78d': None,
#  'ef4': None,
#  '43f': None,
#  '83a': None,
#  '5f3': None,
#  'f36': None,
#  'e0c': None,
#  '503': None,
#  '5fc': None,
#  '7a7': None,
#  'cfb': None,
#  '90e': None,
#  'dac': None,
#  '884': None,
#  '826': None,
#  'af8': None,
#  '0d4': None,
#  '104': None,
#  'e79': None,
#  '523': None,
#  '707': None,
#  'bb6': None,
#  '79f': None,
#  '959': None,
#  '985': None,
#  '85d': None,
#  '378': None,
#  '300': None,
#  'e8b': None,
#  '755': None,
#  '52d': None,
#  '7a0': None,
#  '750': None,
#  'fed': None,
#  '150': None,
#  '14a': None,
#  '9c5': None,
#  '932': None,
#  '5db': None,
#  '257': None,
#  '5c7': None,
#  'dc4': None,
#  '2d9': None,
#  'b58': None,
#  '8d5': None,
#  'f6f': None,
#  '5b0': None,
#  'dff': None,
#  'd50': None,
#  '4b4': None,
#  '4f8': None,
#  '528': None,
#  '997': None,
#  '8ef': None,
#  'e45': None,
#  '60b': None,
#  '325': None,
#  'f9d': None,
#  '8ba': None,
#  '74e': None,
#  '43d': None,
#  'a00': None,
#  '0cf': None,
#  '3aa': None,
#  '6e2': None,
#  'fb1': None,
#  '34e': None,
#  'e16': None,
#  '182': None,
#  '50f': None,
#  '6af': None,
#  'bd1': None,
#  '982': None,
#  'b13': None,
#  '574': None,
#  '2ec': None,
#  '316': None,
#  '259': None,
#  'd4c': None,
#  'f30': None,
#  'ded': None,
#  'b9e': None,
#  '501': None,
#  '27e': None,
#  '54c': None,
#  'd2a': None,
#  '36d': None,
#  '73c': None,
#  'e5c': None,
#  'cfc': None,
#  'abc': None,
#  '3a2': None,
#  '220': None,
#  '890': None,
#  'ef6': None,
#  '295': None,
#  '205': None,
#  'a09': None,
#  'bde': None,
#  '6d3': None,
#  '926': None,
#  'e2d': None,
#  '1b6': None,
#  '0ed': None,
#  '22d': None,
#  'ac2': None,
#  '232': None,
#  '94a': None,
#  '7ef': None,
#  'bf5': None,
#  '70a': None,
#  '008': None,
#  'a43': None,
#  '627': None,
#  '9b5': None,
#  '4ef': None,
#  '735': None,
#  'c6a': None,
#  '4e7': None,
#  '5c1': None,
#  '529': None,
#  'b9f': None,
#  '2ab': None,
#  'd15': None,
#  'c29': None,
#  '354': None,
#  'f4d': None,
#  'f4b': None,
#  '1a0': None,
#  'd68': None,
#  'f79': None,
#  'c41': None,
#  '5df': None,
#  'ce5': None,
#  'aa7': None,
#  'cad': None,
#  'f6e': None,
#  '8c0': None,
#  '724': None,
#  '003': None,
#  'fe0': None,
#  '97f': None,
#  '630': None,
#  '84a': None,
#  'b5f': None,
#  '69a': None,
#  'd82': None,
#  '768': None,
#  '3c8': None,
#  '4dd': None,
#  '860': None,
#  '3bc': None,
#  '016': None,
#  '2f2': None,
#  'c63': None,
#  '2cb': None,
#  '4d9': None,
#  '62d': None,
#  '14b': None,
#  'ec5': None,
#  '3c1': None,
#  '71b': None,
#  '7bc': None,
#  '4b5': None,
#  'b34': None,
#  'e73': None,
#  'e2b': None,
#  'eea': None,
#  'b0d': None,
#  '43c': None,
#  '92d': None,
#  '40e': None,
#  '64c': None,
#  '9bd': None,
#  'cd3': None,
#  'aca': None,
#  '119': None,
#  '5ab': None,
#  'e91': None,
#  'a67': None,
#  '01a': None,
#  '347': None,
#  '7aa': None,
#  'd4d': None,
#  '369': None,
#  '2d0': None,
#  '56e': None,
#  '1c4': None,
#  '037': None,
#  'b6e': None,
#  '67f': None,
#  'e2f': None,
#  '599': None,
#  'b51': None,
#  '2c6': None,
#  '970': None,
#  '25e': None,
#  'a65': None,
#  '96d': None,
#  '3fe': None,
#  'ae0': None,
#  'c9b': None,
#  'e89': None,
#  'd62': None,
#  '207': None,
#  '272': None,
#  'b2e': None,
#  '545': None,
#  '5fe': None,
#  '442': None,
#  '10a': None,
#  '3db': None,
#  '0ac': None,
#  'f49': None,
#  '6ec': None,
#  '161': None,
#  '3b5': None,
#  'beb': None,
#  '5f4': None,
#  'f9c': None,
#  'd2f': None,
#  'c03': None,
#  '184': None,
#  'ce8': None,
#  'e60': None,
#  '62c': None,
#  'fa5': None,
#  'c90': None,
#  'cf0': None,
#  'd88': None,
#  '16b': None,
#  '5ca': None,
#  '7b9': None,
#  '2ef': None,
#  'c20': None,
#  '27a': None,
#  'eb9': None,
#  'cdf': None,
#  'e43': None,
#  'faa': None,
#  '1ac': None,
#  '78a': None,
#  '68a': None,
#  'c74': None,
#  '81f': None,
#  '05f': None,
#  '224': None,
#  '794': None,
#  'e0b': None,
#  'e6e': None,
#  '9a7': None,
#  '8de': None,
#  'd89': None,
#  '290': None,
#  'a34': None,
#  '709': None,
#  '001': None,
#  'dca': None,
#  '394': None,
#  '9a3': None,
#  'a6c': None,
#  'b89': None,
#  '017': None,
#  '18b': None,
#  'f11': None,
#  '17f': None,
#  '73b': None,
#  'c53': None,
#  'eb4': None,
#  '9f8': None,
#  'bcf': None,
#  '954': None,
#  '4a0': None,
#  '1c9': None,
#  '341': None,
#  '1d0': None,
#  '4eb': None,
#  'f02': None,
#  '6e4': None,
#  'b3d': None,
#  '292': None,
#  '639': None,
#  '1d5': None,
#  '93e': None,
#  '243': None,
#  '8bf': None,
#  '722': None,
#  'f4f': None,
#  '564': None,
#  '6d1': None,
#  '14d': None,
#  '6f5': None,
#  '078': None,
#  'a7d': None,
#  '0eb': None,
#  '4b6': None,
#  '077': None,
#  '4cf': None,
#  '234': None,
#  'a41': None,
#  '924': None,
#  '3f7': None,
#  'c54': None,
#  '418': None,
#  '275': None,
#  'a59': None,
#  'a69': None,
#  '66e': None,
#  '5d4': None,
#  '4f6': None,
#  'c4c': None,
#  '784': None,
#  '17e': None,
#  '289': None,
#  'cba': None,
#  '2bb': None,
#  '9c2': None,
#  'e98': None,
#  'dbb': None,
#  'ee5': None,
#  '090': None,
#  '45d': None,
#  '2f4': None,
#  'a42': None,
#  'cf7': None,
#  'eb3': None,
#  '20c': None,
#  '95b': None,
#  'b44': None,
#  'a55': None,
#  '0c1': None,
#  'bc0': None,
#  '3cd': None,
#  '3a0': None,
#  'e00': None,
#  'b99': None,
#  '825': None,
#  'b17': None,
#  '0e0': None,
#  '5e0': None,
#  '4d7': None,
#  '3a1': None,
#  '287': None,
#  '7ff': None,
#  'b81': None,
#  '483': None,
#  '32a': None,
#  'b25': None,
#  'a21': None,
#  '0b0': None,
#  'b49': None,
#  '741': None,
#  '94f': None,
#  'e25': None,
#  '9d4': None,
#  'cbf': None,
#  '6ef': None,
#  '9f7': None,
#  '60c': None,
#  '18c': None,
#  '34f': None,
#  'bac': None,
#  '0c2': None,
#  'ae8': None,
#  '42b': None,
#  '5e8': None,
#  'a44': None,
#  '8ca': None,
#  '21a': None,
#  'bb7': None,
#  '9ee': None,
#  'fbf': None,
#  'd53': None,
#  '921': None,
#  '684': None,
#  '8f0': None,
#  'eda': None,
#  '752': None,
#  '380': None,
#  'ba9': None,
#  '8d6': None,
#  '63c': None,
#  '4ac': None,
#  '2fe': None,
#  '84e': None,
#  'dae': None,
#  'c65': None,
#  '776': None,
#  ...}

# %%
# Pre-processing 
# Create dictionary <key,value> 
import hashlib
from collections import OrderedDict 
fileName = 'syllables.txt' 
# Create hash key
    # TODO: Remember to change mode to 'a' 
    # So that next time function won't rewrite 
hashList = []
with open(fileName,mode = 'r',encoding= 'utf-8') as file: 
    rawFileInput = file.readlines() 
    for line in rawFileInput: 
        line = hashlib.md5(line.encode()).hexdigest()[:3:]
        hashList.append(line)

def removeDuplicate(inputList): 
    return list(OrderedDict.fromkeys(inputList))

removeDuplicate(hashList)

def fillKeyOnly(listOfKey,myDict):
    myDict = {key: [] for key in listOfKey} 
    return myDict 

def fillValueOnly(listOfValue,myDict): 
    for value in listOfValue: 
        hashValue = hashlib.md5(value.encode()).hexdigest()[:3:]
        myDict[hashValue].append(value)
    return myDict
myDict = {}
myDict = fillKeyOnly(hashList,myDict)
myDict = fillValueOnly(rawFileInput,myDict)

print(myDict)
# Out:
# 3e': ['NGÕ\n'], 'e56': ['NGỎ\n', 'NHỐ\n', 'VÙA\n'], '282': ['NGỚ\n'], 'a85': ['NGỜ\n', 'NGỪM\n', 'PHÓNG\n'], '29a': ['NGOA\n'], 'a94': ['NGỌA\n'], '346': ['NGOÁC\n'], '35e': ['NGOẮC\n'], '461': ['NGOẶC\n', 'VONG\n'], '329': ['NGOẠC\n', 'NHÁI\n', 'QUÁI\n'], 'd04': ['NGOÁCH\n'], '938': ['NGOẠCH\n'], '9ae': ['NGOAI\n'], 'f7d': ['NGOẢI\n', 'PHÀNG\n'], 'e7e': ['NGOÀM\n'], '84d': ['NGOẰN\n', 'TIA\n'], 'a22': ['NGOẲN\n', 'VÂM\n'], 'c50': ['NGOĂNG\n'], 'f08': ['NGOẲNG\n', 'TỔ\n'], '2d1': ['NGOÁP\n', 'TƯỚNG\n', 'XO\n'], 'b36': ['NGOẶT\n', 'RÁ\n', 'RẺN\n'], '102': ['NGOAY\n'], '7ea': ['NGỘC\n'], '05e': ['NGOEO\n', 'SUÔN\n'], '82e': ['NGOẺO\n', 'SẤM\n'], 'd63': ['NGƠI\n', 'VÀ\n'], '4bd': ['NGỜI\n'], '742': ['NGỒM\n', 'PHẠM\n', 'PHỒM\n', 'VƯỢT\n'], 'd43': ['NGỎM\n', 'SẸO\n', 'VẤT\n', 'VẠY\n'], '677': ['NGỜM\n'], 'd05': ['NGON\n', 'QUỴT\n', 'RỎN\n'], 'b66': ['NGÔN\n', 'RỖI\n', 'VỤN\n', 'XỤT\n'], 'da2': ['NGỒN\n'], '0ba': ['NGÒNG\n', 'SỨA\n', 'THẨM\n'], '4db': ['NGỎNG\n', 'TỐT\n'], '64a': ['NGỌNG\n', 'VÉP\n'], 'f82': ['NGỢP\n', 'NGUYỄN\n'], '898': ['NGỌT\n'], '535': ['NGỨ\n', 'TỐNG\n'], 'bec': ['NGỪ\n', 'QUẤC\n', 'RỠ\n', 'TRÒ\n', 'VO\n'], '2b2': ['NGỰ\n', 'VÙ\n', 'XỘN\n'], 'b5c': ['NGỤA\n', 'NHẤC\n'], '858': ['NGỪA\n'], 'd1e': ['NGỬA\n', 'TỬA\n', 'XÓM\n'], '126': ['NGUÂY\n', 'NIỀN\n'], '201': ['NGUẨY\n', 'TRÓC\n'], '9b7': ['NGUỆCH\n', 'VẢNH\n'], 'f5e': ['NGỦI\n'], '0b4': ['NGUN\n', 'ƯNG\n'], 'ca2': ['NGŨN\n'], 'f7f': ['NGỦN\n'], '7ad': ['NGÚNG\n', 'TRÉC\n'], '827': ['NGỦNG\n', 'SIỂNG\n', 'THỤI\n'], '62a': ['NGƯNG\n'], '056': ['NGỨNG\n', 'PHỊ\n', 'TẮN\n'], '241': ['NGỬNG\n'], 'bbf': ['NGƯỢC\n', 'TŨM\n'], '433': ['NGUÔI\n'], 'f1c': ['NGUỒI\n'], '7ba': ['NGUỘI\n', 'RƯỜNG\n'], 'f66': ['NGƯƠI\n', 'THỀU\n'], '49a': ['NGUỒN\n', 'XẸC\n'], 'b26': ['NGƯỜNG\n'], '71f': ['NGƯỞNG\n', 'TỒNG\n', 'XẺ\n'], '41e': ['NGUYÊN\n', 'THỘC\n', 'VIẾNG\n'], '2eb': ['NGUYỀN\n'], 'ec3': ['NHÃ\n', 'TRÁI\n'], 'ad6': ['NHẠ\n', 'NƯỜM\n'], '636': ['NHÁC\n', 'THỤ\n'], '60d': ['NHẮC\n'], 'fbd': ['NHẠC\n', 'THẦN\n'], '476': ['NHÀI\n'], '876': ['NHẬM\n', 'SY\n'], '404': ['NHÀN\n'], '3a5': ['NHĂN\n', 'PI\n'], '28d': ['NHẶN\n'], '976': ['NHÂN\n', 'XÂU\n'], '9e2': ['NHẦN\n', 'RỊN\n'], '5be': ['NHẪN\n'], '3d0': ['NHẨN\n'], 'd83': ['NHẮNG\n', 'SỊ\n'], 'fde': ['NHÂNG\n', 'TÒI\n'], 'e9c': ['NHANH\n'], '43b': ['NHẢNH\n'], '37f': ['NHÁO\n'], '9da': ['NHẢO\n'], '3f9': ['NHÁP\n', 'SIU\n', 'THẨU\n', 'TRỤT\n'], 'd14': ['NHẬP\n'], '24a': ['NHẮT\n', 'VÙN\n'], '67d': ['NHẤT\n'], 'a56': ['NHÁU\n', 'THOĂN\n'], 'dde': ['NHÂU\n', 'NHƠI\n'], 'd49': ['NHẨU\n', 'PHĂM\n', 'THỮNG\n'], 'e12': ['NHÁY\n', 'XÒE\n'], '19c': ['NHÀY\n'], '706': ['NHẤY\n', 'TÀM\n'], '21b': ['NHẦY\n'], '0e5': ['NHẪY\n', 'PHÌNH\n', 'XÃ\n'], 'd3d': ['NHẬY\n', 'THUỘM\n'], '6c2': ['NHÉ\n'], 'd7c': ['NHÊ\n'], '4f4': ['NHỂ\n', 'PHỀU\n'], 'f56': ['NHẼ\n', 'TỦI\n'], '014': ['NHÈM\n', 'ÔM\n', 'TÍC\n', 'TỘC\n'], '89d': ['NHÉN\n'], 'a84': ['NHẸN\n', 'NHƯỚNG\n', 'NỚI\n', 'TRẤU\n'], '696': ['NHẾNH\n', 'NHỢ\n', 'NUỘC\n'], 'fc8': ['NHÈO\n'], '7db': ['NHẸO\n'], '30d': ['NHÉP\n', 'SẠM\n'], '863': ['NHẸP\n', 'VẬN\n'], 'd5a': ['NHỆT\n', 'QUÈN\n', 'RÉO\n'], '5b2': ['NHẸT\n'], '2e3': ['NHỆU\n', 'THẾT\n'], '5ee': ['NHI\n', 'TÍU\n', 'TRỐNG\n', 'VỪA\n'], 'd12': ['NHIỄN\n', 'PHÁCH\n'], '348': ['NHIỆT\n', 'SỔ\n', 'TÍCH\n'], '70c': ['NHIÊU\n', 'OÁN\n', 'TRẨN\n', 'TUỒN\n', 'VÊN\n', 'VY\n'], '522': ['NHIỄU\n', 'VÓN\n'], '08d': ['NHIM\n', 'THƯỚC\n'], '20f': ['NHÍN\n', 'Ô\n'], '578': ['NHÍNH\n'], '91a': ['NHO\n', 'PHỊCH\n'], 'caa': ['NHÒ\n', 'Ủ\n'], '332': ['NHÔ\n', 'QUYỀNH\n'], 'ce6': ['NHỌ\n', 'TÕE\n'], 'e48': ['NHỚ\n'], 'f6c': ['NHỠ\n', 'RỎ\n'], '1ce': ['NHOÀI\n', 'PHẨM\n', 'SỊCH\n', 'TÀNH\n', 'VIÊNG\n'], '58b': ['NHOÀM\n'], '1fa': ['NHOẠNG\n', 'RẶNG\n'], 'be7': ['NHOÁY\n', 'THỦNG\n', 'XOẸT\n'], 'b8e': ['NHỐC\n'], '26f': ['NHỌC\n'], 'd79': ['NHOE\n', 'THƯỜN\n'], '4a6': ['NHÓE\n'], 'd52': ['NHOEN\n'], 'c15': ['NHÔI\n'], '89e': ['NHỐI\n', 'RANG\n'], 'c92': ['NHỘI\n'], '8bd': ['NHỜI\n'], '193': ['NHỒM\n', 'THẤT\n'], 'c32': ['NHƠM\n', 'TĨNH\n'], '856': ['NHỜM ...

# %%
search = input("Enter state name:")  
print(myDict.get(search), "từ muốn tìm: ", search)
# Out:
# None từ muốn tìm:  gg3

# %%
# Out:
# Số từ xuất hiện trong input 0
